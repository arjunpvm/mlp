# %% [markdown]
# # Introduction to Scikit-Learn
# ![Thu May  1 09:30:57 AM IST 2025.png](data:image/png;base64,...)

# %% [markdown]
# ![Thu May  1 09:31:47 AM IST 2025.png](data:image/png;base64,...)

# %% [markdown]
# ![Thu May  1 09:32:23 AM IST 2025.png](data:image/png;base64,...)

# %% [markdown]
# ![Thu May  1 09:33:29 AM IST 2025.png](data:image/png;base64,...)

# %% [markdown]
# ![Fri May  2 07:59:54 AM IST 2025.png](data:image/png;base64,...)

# %% [markdown]
# ![Fri May  2 08:08:22 AM IST 2025.png](data:image/png;base64,...)

# %% [markdown]
# * `sklearn.multioutput` implements multi-output classification and regression.
# * `sklearn.clusters` implements many popular clustering algorithms.

# %% [markdown]
# ### Model Evaluation API
# `sklearn.metrics` implements different APIs for model evaluation
# * classification
# * regression
# * clustering
#
# ### Model Selection API
# `sklearn.model_selection` implements various model selection strategies like **cross validation, tuning hyperparameters** and **plotting learning cureves**
#
# ### Modle Inspection API
# `sklearn.model_inspection` includes tools for model inspection
#
# #### To know:
# * It is not possible to remenber each and every sklearn API.
# * Remember high level modules and API design principles.
# * use documentation for more like this:
# ```python
# from sklearn.linear_model import LinearRegression
# ?LinearRegression
# ```
